# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib notebook

n_animals = 100
n_steps = 1000
dt = 0.1

x = np.ones(n_animals)*0.5
y = np.ones(n_animals)*0.5

fig = plt.figure(figsize = (3,3));
plt.xlim(0,1);
plt.ylim(0,1);
#plt.show(); not needed 

for i in range(n_steps):    #theres definitely something not right here, the deer move in a solid dot herd. also it breaks at 100
    speed = np.random.uniform(-1,1) 
    x = x + speed*dt
    y = y + speed*dt
    if((x[i] >= 1) or (x[i] <= 0)): speed = -1*speed
    if((y[i] >= 1) or (y[i] <= 0)): speed = -1*speed
    #np.maximum(x,0)  np.minimum(x,1)   np.maximum(y,0)  np.minimum(y,1)
                
    plt.cla()
    plt.plot(x, y, 'k.', markersize = 1);
    plt.xlim(0,1);
    plt.ylim(0,1);
    fig.canvas.draw();
    time.sleep(0.001)
# Out:
# <img src="data:image/png;base64,..." width="300">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-9486da4c49a9> in <module>
#      17     x = x + speed*dt
#      18     y = y + speed*dt
# ---> 19     if((x[i] >= 1) or (x[i] <= 0)): speed = -1*speed
#      20     if((y[i] >= 1) or (y[i] <= 0)): speed = -1*speed
#      21     #np.maximum(x,0)  np.minimum(x,1)   np.maximum(y,0)  np.minimum(y,1)
#
# IndexError: index 100 is out of bounds for axis 0 with size 100
